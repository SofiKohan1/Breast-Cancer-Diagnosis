# %%
# Data, Datasets & Utils
import pandas as pd
from pandas.plotting import scatter_matrix
import pprint
import numpy as np
from time import time
from numpy import log2 as log

# Validation methods
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold

# Metrics
from sklearn import metrics
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Classifiers
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB

# Hyper-parameter optimisation
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# Feature selection & feature engineering
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.decomposition import PCA
from sklearn import preprocessing

# Stats
from scipy.stats import randint as sp_randint
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import shapiro     # Shapiro Wilk
from scipy.stats import normaltest  # D’Agostino’s K^2
from scipy.stats import anderson    # Anderson-Darling
from scipy.stats import ttest_ind    # independent student t-test; assumes normality
from scipy.stats import mannwhitneyu # non-parametric; doesn't assume normality

# Visualisation
import matplotlib.pyplot as plot 
import seaborn as sns
from IPython.display import SVG
from graphviz import Source
from IPython.display import display
from sklearn.tree import export_graphviz

# %%
df = pd.read_csv('data/breast-cancer.csv')

# %%
df.boxplot(column = 'Area (Mean)', by = 'Diagnosis');
plot.title('Area (Mean) \n\n')

import seaborn as sns
#sns.lmplot(data=df, x='Diagnosis', y='Smoothness (Mean)')

# %%
df.boxplot(column = 'Radius (Mean)', by = 'Diagnosis');
plot.title('Radius (Mean) \n\n')
sns.lmplot(data=df, x='Radius (Mean)', y='Compactness (Mean)', hue='Diagnosis')

# %%
df.boxplot(column = 'Texture (Mean)', by = 'Diagnosis');
plot.title('Texture (Mean) \n\n')
sns.lmplot(data=df, x='Area (Mean)', y='Texture (Mean)', hue='Diagnosis')

# %%
df.boxplot(column = 'Perimeter (Mean)', by = 'Diagnosis');
plot.title('Perimeter (Mean) \n\n')

sns.lmplot(data=df, x='Perimeter (Mean)', y='Concavity (Mean)', hue='Diagnosis')

# %%
df.boxplot(column = 'Smoothness (Mean)', by = 'Diagnosis');
plot.title('Smoothness (Mean) \n\n')

sns.lmplot(data=df, x='Smoothness (Mean)', y='Concave Points (Mean)', hue='Diagnosis')

# %%
df.boxplot(column = 'Concavity (Mean)', by = 'Diagnosis');
plot.title('Concavity (Mean) \n\n')
# Out:
# Text(0.5, 1.0, 'Concavity (Mean) \n\n')

# %%
df.boxplot(column = 'Concave Points (Mean)', by = 'Diagnosis');
plot.title('Concave Ponints (Mean) \n\n')
# Out:
# Text(0.5, 1.0, 'Concave Ponints (Mean) \n\n')

# %%
df.boxplot(column = 'Symmetry (Mean)', by = 'Diagnosis');
plot.title('Symmetry (Mean) \n\n')

sns.lmplot(data=df, x='Area (Mean)', y='Symmetry (Mean)', hue='Diagnosis')

# %%
df.boxplot(column = 'Fractal Dimension (Mean)', by = 'Diagnosis');
plot.title('Fractal Dimension (Mean) \n\n')

#sns.lmplot(data=df, x='Diagnosis', y='Fractal Dimension (Mean)')
# Out:
# Text(0.5, 1.0, 'Fractal Dimension (Mean) \n\n')

# %%
##Outliers from selected features from the recrusive feature elimination, for the following ones: 
#area (worst) ' Area (Worst)'
#concave points(worst) 'Concave Points (Worst)'
#texture(mean) 'Texture (Mean)'
#concavity(mean) 'Concavity (Mean)'
#compactness(error) ' Compactness (Error)
#area(mean) 'Area (Mean)'

# %%
df.boxplot(column = 'Area (Mean)', by = 'Diagnosis');
plot.title('Area (Mean) \n\n')
# Out:
# Text(0.5, 1.0, 'Area (Mean) \n\n')

# %%
df.boxplot(column = ' Area (Worst)', by = 'Diagnosis');
plot.title('Area (Worst) \n\n')
# Out:
# Text(0.5, 1.0, 'Area (Worst) \n\n')

# %%
df.boxplot(column = 'Concave Points (Worst)', by = 'Diagnosis');
plot.title('Concave Points (Worst) \n\n')
# Out:
# Text(0.5, 1.0, 'Concave Points (Worst) \n\n')

# %%
df.boxplot(column = 'Texture (Mean)', by = 'Diagnosis');
plot.title('Texture (Mean) \n\n')
# Out:
# Text(0.5, 1.0, 'Texture (Mean) \n\n')

# %%
df.boxplot(column = 'Concavity (Mean)', by = 'Diagnosis');
plot.title('Concavity (Mean) \n\n')
# Out:
# Text(0.5, 1.0, 'Concavity (Mean) \n\n')

# %%
df.boxplot(column = 'Compactness (Mean)', by = 'Diagnosis');
plot.title('Compactness (Mean) \n\n')
# Out:
# Text(0.5, 1.0, 'Compactness (Mean) \n\n')
